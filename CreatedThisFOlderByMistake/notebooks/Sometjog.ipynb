# %%
                                                                                                                                                                                                                                        from jupyterthemes import get_themes
import jupyterthemes as jt
from jupyterthemes.stylefx import set_nb_theme
set_nb_theme('onedork')
# Out:
# <style> div#notebook {
#  font-family: sans-serif;
#  font-size: 13pt;
#  line-height: 170%;
#  color: #b5c2d9;
#  -webkit-font-smoothing: antialiased !important;
#  padding-top: 25px !important;
# }
# body,
# div.body {
#  font-family: sans-serif;
#  font-size: 13pt;
#  color: #899ab8;
#  background-color: #1d1e23;
#  background: #1d1e23;
#  -webkit-font-smoothing: antialiased !important;
# }
# body.notebook_app {
#  padding: 0;
#  background-color: #1d1e23;
#  background: #1d1e23;
#  padding-right: 0px !important;
#  overflow-y: hidden;
# }
# a {
#  font-family: sans-serif;
#  color: #899ab8;
#  -webkit-font-smoothing: antialiased !important;
# }
# a:hover,
# a:focus {
#  color: #bbc2e0;
#  -webkit-font-smoothing: antialiased !important;
# }
# div#maintoolbar {
#  position: absolute;
#  width: 90%;
#  margin-left: -10%;
#  padding-right: 8%;
#  float: left;
#  background: transparent !important;
# }
# #maintoolbar {
#  margin-bottom: -3px;
#  margin-top: 0px;
#  border: 0px;
#  min-height: 27px;
#  padding-top: 2px;
#  padding-bottom: 0px;
# }
# #maintoolbar .container {
#  width: 75%;
#  margin-right: auto;
#  margin-left: auto;
# }
# .list_header,
# div#notebook_list_header.row.list_header {
#  font-size: 14pt;
#  color: #bbc2e0;
#  background-color: transparent;
#  height: 35px;
# }
# i.fa.fa-folder {
#  display: inline-block;
#  font: normal normal normal 14px "FontAwesome";
#  font-family: "FontAwesome" !important;
#  text-rendering: auto;
#  -webkit-font-smoothing: antialiased;
#  font-size: 18px;
#  -moz-osx-font-smoothing: grayscale;
# }
# #running .panel-group .panel .panel-heading {
#  font-size: 14pt;
#  color: #899ab8;
#  padding: 8px 8px;
#  background: #2e3642;
#  background-color: #2e3642;
# }
# #running .panel-group .panel .panel-heading a {
#  font-size: 14pt;
#  color: #899ab8;
# }
# #running .panel-group .panel .panel-heading a:focus,
# #running .panel-group .panel .panel-heading a:hover {
#  font-size: 14pt;
#  color: #899ab8;
# }
# #running .panel-group .panel .panel-body .list_container .list_item {
#  background: #384152;
#  background-color: #384152;
#  padding: 2px;
#  border-bottom: 2px solid rgba(80,92,133,.22);
# }
# #running .panel-group .panel .panel-body .list_container .list_item:hover {
#  background: #384152;
#  background-color: #384152;
# }
# #running .panel-group .panel .panel-body {
#  padding: 2px;
# }
# button#refresh_running_list {
#  border: none !important;
# }
# button#refresh_cluster_list {
#  border: none !important;
# }
# div.running_list_info.toolbar_info {
#  font-size: 15px;
#  padding: 4px 0 4px 0;
#  margin-top: 5px;
#  margin-bottom: 8px;
#  height: 24px;
#  line-height: 24px;
#  text-shadow: none;
# }
# .list_placeholder {
#  font-weight: normal;
# }
# #tree-selector {
#  padding: 0px;
#  border-color: transparent;
# }
# #project_name > ul > li > a > i.fa.fa-home {
#  color: #7aa05d;
#  font-size: 17pt;
#  display: inline-block;
#  position: static;
#  padding: 0px 0px;
#  font-weight: normal;
#  text-align: center;
#  vertical-align: text-top;
# }
# .fa-folder:before {
#  color: #4c8be2;
# }
# .fa-arrow-up:before {
#  font-size: 14px;
# }
# .fa-arrow-down:before {
#  font-size: 14px;
# }
# span#last-modified.btn.btn-xs.btn-default.sort-action:hover .fa,
# span#sort-name.btn.btn-xs.btn-default.sort-action:hover .fa {
#  color: #7aa05d;
# }
# .folder_icon:before {
#  display: inline-block;
#  font: normal normal normal 14px/1 FontAwesome;
#  font-size: inherit;
#  text-rendering: auto;
#  -webkit-font-smoothing: antialiased;
#  -moz-osx-font-smoothing: grayscale;
#  content: "\f07b";
#  color: #4c8be2;
# }
# .notebook_icon:before {
#  display: inline-block;
#  font: normal normal normal 14px/1 FontAwesome;
#  font-size: inherit;
#  text-rendering: auto;
#  -webkit-font-smoothing: antialiased;
#  -moz-osx-font-smoothing: grayscale;
#  content: "\f02d";
#  position: relative;
#  color: #94c273 !important;
#  top: 0px;
# }
# .file_icon:before {
#  display: inline-block;
#  font: normal normal normal 14px/1 FontAwesome;
#  font-size: inherit;
#  text-rendering: auto;
#  -webkit-font-smoothing: antialiased;
#  -moz-osx-font-smoothing: grayscale;
#  content: "\f15b";
#  position: relative;
#  top: 0px;
#  color: #899ab8 !important;
# }
# #project_name a {
#  display: inline-flex;
#  padding-left: 7px;
#  margin-left: -2px;
#  text-align: -webkit-auto;
#  vertical-align: baseline;
#  font-size: 18px;
# }
# div#notebook_toolbar div.dynamic-instructions {
#  font-family: sans-serif;
#  font-size: 17px;
#  color: #526488;
# }
# span#login_widget > .button,
# #logout {
#  font-family: "Proxima Nova", sans-serif;
#  color: #899ab8;
#  background: transparent;
#  background-color: transparent;
#  border: 2px solid #303542;
#  font-weight: normal;
#  box-shadow: none;
#  text-shadow: none;
#  border-radius: 3px;
#  margin-right: 10px;
#  padding: 2px 7px;
# }
# span#login_widget > .button:hover,
# #logout:hover {
#  color: #7aa05d;
#  background-color: transparent;
#  background: transparent;
#  border: 2px solid #7aa05d;
#  background-image: none;
#  box-shadow: none !important;
#  border-radius: 3px;
# }
# span#login_widget > .button:focus,
# #logout:focus,
# span#login_widget > .button.focus,
# #logout.focus,
# span#login_widget > .button:active,
# #logout:active,
# span#login_widget > .button.active,
# #logout.active,
# .open > .dropdown-togglespan#login_widget > .button,
# .open > .dropdown-toggle#logout {
#  color: #d8dcee;
#  background-color: #899ab8;
#  background: #899ab8;
#  border-color: #899ab8;
#  background-image: none;
#  box-shadow: none !important;
#  border-radius: 2px;
# }
# body > #header #header-container {
#  padding-bottom: 0px;
#  padding-top: 4px;
#  box-sizing: border-box;
#  -moz-box-sizing: border-box;
#  -webkit-box-sizing: border-box;
# }
# body > #header {
#  background: #1d1e23;
#  background-color: #1d1e23;
#  position: relative;
#  z-index: 100;
# }
# .list_container {
#  font-size: 13pt;
#  color: #899ab8;
#  border: none;
#  text-shadow: none !important;
# }
# .list_container > div {
#  border-bottom: 1px solid rgba(80,92,133,.22);
#  font-size: 13pt;
# }
# .list_header > div,
# .list_item > div {
#  padding-top: 6px;
#  padding-bottom: 2px;
#  padding-left: 0px;
# }
# .list_header > div .item_link,
# .list_item > div .item_link {
#  margin-left: -1px;
#  vertical-align: middle;
#  line-height: 22px;
#  font-size: 13pt;
# }
# .item_icon {
#  color: #4c8be2;
#  font-size: 13pt;
#  vertical-align: middle;
# }
# .list_item input:not([type="checkbox"]) {
#  padding-right: 0px;
#  height: 1.75em;
#  width: 25%;
#  margin: 0px 0 0;
#  margin-top: 0px;
# }
# .list_header > div .item_link,
# .list_item > div .item_link {
#  margin-left: -1px;
#  vertical-align: middle;
#  line-height: 1.5em;
#  font-size: 12pt;
#  display: inline-table;
#  position: static;
# }
# #button-select-all {
#  height: 34px;
#  min-width: 55px;
#  z-index: 0;
#  border: none !important;
#  padding-top: 0px;
#  padding-bottom: 0px;
#  margin-bottom: 0px;
#  margin-top: 0px;
#  left: -3px;
#  border-radius: 0px !important;
# }
# #button-select-all:focus,
# #button-select-all:active:focus,
# #button-select-all.active:focus,
# #button-select-all.focus,
# #button-select-all:active.focus,
# #button-select-all.active.focus {
#  background-color: #303542 !important;
#  background: #303542 !important;
# }
# button#tree-selector-btn {
#  height: 34px;
#  font-size: 12.0pt;
#  border: none;
#  left: 0px;
#  border-radius: 0px !important;
# }
# input#select-all.pull-left.tree-selector {
#  margin-left: 7px;
#  margin-right: 2px;
#  margin-top: 2px;
#  top: 4px;
# }
# input[type="radio"],
# input[type="checkbox"] {
#  margin-top: 1px;
#  line-height: normal;
# }
# .delete-button {
#  border: none !important;
# }
# i.fa.fa-trash {
#  font-size: 13.5pt;
# }
# .list_container a {
#  font-size: 16px;
#  color: #899ab8;
#  border: none;
#  text-shadow: none !important;
#  font-weight: normal;
#  font-style: normal;
# }
# div.list_container a:hover {
#  color: #bbc2e0;
# }
# .list_header > div input,
# .list_item > div input {
#  margin-right: 7px;
#  margin-left: 12px;
#  vertical-align: baseline;
#  line-height: 22px;
#  position: relative;
#  top: -1px;
# }
# div.list_item:hover {
#  background-color: rgba(80,90,133,.06);
# }
# .breadcrumb > li {
#  font-size: 12.0pt;
#  color: #899ab8;
#  border: none;
#  text-shadow: none !important;
# }
# .breadcrumb > li + li:before {
#  content: "/\00a0";
#  padding: 0px;
#  color: #899ab8;
#  font-size: 18px;
# }
# #project_name > .breadcrumb {
#  padding: 0px;
#  margin-bottom: 0px;
#  background-color: transparent;
#  font-weight: normal;
#  margin-top: -2px;
# }
# ul#tabs a {
#  font-family: sans-serif;
#  font-size: 13.5p

# %%
import cv2
import pickle
import imageio

import numpy as np
import pandas as pd

from collections import Counter
from sklearn.cluster import KMeans
from tqdm import tqdm_notebook as tqdm

# %%
ano_path = "Friends_20-_20S03E06_20-_20The_20One_20With_20The_20Flashback.mp4-annotations.pkl"
temp = pickle.load(open(ano_path, "rb"))
# temp = pickle.load(open(path, "rb"))
category_index = pickle.load(open("category_index.pkl", "rb"))
annotations = temp['frames']
# category_index = temp['category_index']

# %%
print("Total Frames of the video", len(annotations))
# Out:
# Total Frames of the video 32768

# %%
save_key_vectors_from_annotations(ano_path)

# %%
vecs = pickle.load(
        open(f"{ano_path}-VECS.pkl", "rb")
    )

idxs = pickle.load(
        open(f"{ano_path}-FRAME-INDEXES.pkl", "rb")
    )

# %%
len(vecs), len(idxs)
# Out:
# (2536, 2536)

# %%
def save_key_vectors_from_annotations(
    path,
    fps=25
    ):
    '''
    Converting the annotations and saving things
    '''
    FPS = fps
    start = 0

    vecs = []
    fidxs = []
    annotation = pickle.load(open(path, "rb"))

    for end in range(FPS, len(annotation['frames']), FPS):
        try:
            batch = annotation['frames'][start : end]
            fno, frame_vecs = get_key_from_batch_with_frame_nos(batch, start, category_index)
            if fno and frame_vecs:
                for _fno, _vec in zip(fno, frame_vecs):
                    fidxs.append(_fno)
                    vecs.append(_vec)

        except Exception as e:
            print(f"{start}-{end}-{e}")
        start = end

    pickle.dump(
        vecs,
        open(f"{path}-VECS.pkl", "wb")
    )

    pickle.dump(
        fidxs,
        open(f"{path}-FRAME-INDEXES.pkl", "wb")
    )

# %%
start, end
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-28efead81879> in <module>
# ----> 1 start, end
#
# NameError: name 'end' is not defined

# %%
start, end
# Out:
# (0, 0)

# %%
annotation
# Out:
# {'frames': [{'annotations': {'detection_classes': [],
#     'detection_scores': [],
#     'detection_boxes': []}},
#   {'annotations': {'detection_classes': [],
#     'detection_scores': [],
#     'detection_boxes': []}},
#   {'annotations': {'detection_classes': [],
#     'detection_scores': [],
#     'detection_boxes': []}},
#   {'annotations': {'detection_classes': [],
#     'detection_scores': [],
#     'detection_boxes': []}},
#   {'annotations': {'detection_classes': [],
#     'detection_scores': [],
#     'detection_boxes': []}},
#   {'annotations': {'detection_classes': [],
#     'detection_scores': [],
#     'detection_boxes': []}},
#   {'annotations': {'detection_classes': [],
#     'detection_scores': [],
#     'detection_boxes': []}},
#   {'annotations': {'detection_classes': [],
#     'detection_scores': [],
#     'detection_boxes': []}},
#   {'annotations': {'detection_classes': [],
#     'detection_scores': [],
#     'detection_boxes': []}},
#   {'annotations': {'detection_classes': [],
#     'detection_scores': [],
#     'detection_boxes': []}},
#   {'annotations': {'detection_classes': [],
#     'detection_scores': [],
#     'detection_boxes': []}},
#   {'annotations': {'detection_classes': [],
#     'detection_scores': [],
#     'detection_boxes': []}},
#   {'annotations': {'detection_classes': [],
#     'detection_scores': [],
#     'detection_boxes': []}},
#   {'annotations': {'detection_classes': [],
#     'detection_scores': [],
#     'detection_boxes': []}},
#   {'annotations': {'detection_classes': [],
#     'detection_scores': [],
#     'detection_boxes': []}},
#   {'annotations': {'detection_classes': [],
#     'detection_scores': [],
#     'detection_boxes': []}},
#   {'annotations': {'detection_classes': [],
#     'detection_scores': [],
#     'detection_boxes': []}},
#   {'annotations': {'detection_classes': [],
#     'detection_scores': [],
#     'detection_boxes': []}},
#   {'annotations': {'detection_classes': [],
#     'detection_scores': [],
#     'detection_boxes': []}},
#   {'annotations': {'detection_classes': [],
#     'detection_scores': [],
#     'detection_boxes': []}},
#   {'annotations': {'detection_classes': [],
#     'detection_scores': [],
#     'detection_boxes': []}},
#   {'annotations': {'detection_classes': [],
#     'detection_scores': [],
#     'detection_boxes': []}},
#   {'annotations': {'detection_classes': [],
#     'detection_scores': [],
#     'detection_boxes': []}},
#   {'annotations': {'detection_classes': [],
#     'detection_scores': [],
#     'detection_boxes': []}},
#   {'annotations': {'detection_classes': [],
#     'detection_scores': [],
#     'detection_boxes': []}},
#   {'annotations': {'detection_classes': [],
#     'detection_scores': [],
#     'detection_boxes': []}},
#   {'annotations': {'detection_classes': [],
#     'detection_scores': [],
#     'detection_boxes': []}},
#   {'annotations': {'detection_classes': [],
#     'detection_scores': [],
#     'detection_boxes': []}},
#   {'annotations': {'detection_classes': [],
#     'detection_scores': [],
#     'detection_boxes': []}},
#   {'annotations': {'detection_classes': [],
#     'detection_scores': [],
#     'detection_boxes': []}},
#   {'annotations': {'detection_classes': [],
#     'detection_scores': [],
#     'detection_boxes': []}},
#   {'annotations': {'detection_classes': [],
#     'detection_scores': [],
#     'detection_boxes': []}},
#   {'annotations': {'detection_classes': [],
#     'detection_scores': [],
#     'detection_boxes': []}},
#   {'annotations': {'detection_classes': [],
#     'detection_scores': [],
#     'detection_boxes': []}},
#   {'annotations': {'detection_classes': [],
#     'detection_scores': [],
#     'detection_boxes': []}},
#   {'annotations': {'detection_classes': [],
#     'detection_scores': [],
#     'detection_boxes': []}},
#   {'annotations': {'detection_classes': [],
#     'detection_scores': [],
#     'detection_boxes': []}},
#   {'annotations': {'detection_classes': [],
#     'detection_scores': [],
#     'detection_boxes': []}},
#   {'annotations': {'detection_classes': [],
#     'detection_scores': [],
#     'detection_boxes': []}},
#   {'annotations': {'detection_classes': [],
#     'detection_scores': [],
#     'detection_boxes': []}},
#   {'annotations': {'detection_classes': [],
#     'detection_scores': [],
#     'detection_boxes': []}},
#   {'annotations': {'detection_classes': [],
#     'detection_scores': [],
#     'detection_boxes': []}},
#   {'annotations': {'detection_classes': [],
#     'detection_scores': [],
#     'detection_boxes': []}},
#   {'annotations': {'detection_classes': [],
#     'detection_scores': [],
#     'detection_boxes': []}},
#   {'annotations': {'detection_classes': [],
#     'detection_scores': [],
#     'detection_boxes': []}},
#   {'annotations': {'detection_classes': [],
#     'detection_scores': [],
#     'detection_boxes': []}},
#   {'annotations': {'detection_classes': [],
#     'detection_scores': [],
#     'detection_boxes': []}},
#   {'annotations': {'detection_classes': [],
#     'detection_scores': [],
#     'detection_boxes': []}},
#   {'annotations': {'detection_classes': [],
#     'detection_scores': [],
#     'detection_boxes': []}},
#   {'annotations': {'detection_classes': [],
#     'detection_scores': [],
#     'detection_boxes': []}},
#   {'annotations': {'detection_classes': [],
#     'detection_scores': [],
#     'detection_boxes': []}},
#   {'annotations': {'detection_classes': [],
#     'detection_scores': [],
#     'detection_boxes': []}},
#   {'annotations': {'detection_classes': [],
#     'detection_scores': [],
#     'detection_boxes': []}},
#   {'annotations': {'detection_classes': [],
#     'detection_scores': [],
#     'detection_boxes': []}},
#   {'annotations': {'detection_classes': [],
#     'detection_scores': [],
#     'detection_boxes': []}},
#   {'annotations': {'detection_classes': [],
#     'detection_scores': [],
#     'detection_boxes': []}},
#   {'annotations': {'detection_classes': [],
#     'detection_scores': [],
#     'detection_boxes': []}},
#   {'annotations': {'detection_classes': ['person'],
#     'detection_scores': [0.6286621],
#     'detection_boxes': array([[0.07324207, 0.54495955, 0.6330163 , 0.8629242 ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'person', 'chair'],
#     'detection_scores': [0.8450505, 0.6343393, 0.57531196],
#     'detection_boxes': array([[0.07557255, 0.5317842 , 0.6457874 , 0.86686134],
#            [0.14508948, 0.12320918, 0.7302731 , 0.33802968],
#            [0.48720542, 0.02898086, 0.9857373 , 0.25152847]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person'],
#     'detection_scores': [0.8623741],
#     'detection_boxes': array([[0.06907547, 0.5338415 , 0.62367135, 0.8574282 ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person'],
#     'detection_scores': [0.9095405],
#     'detection_boxes': array([[0.07727909, 0.5294515 , 0.6214286 , 0.85189736]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'chair'],
#     'detection_scores': [0.9272918, 0.55031127],
#     'detection_boxes': array([[0.07882136, 0.5525466 , 0.622215  , 0.85586774],
#            [0.47478053, 0.02738498, 0.9885031 , 0.25448704]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'chair', 'person'],
#     'detection_scores': [0.9142917, 0.5650237, 0.50612485],
#     'detection_boxes': array([[0.07290536, 0.5225434 , 0.62349486, 0.85574895],
#            [0.47740248, 0.02319607, 0.9861976 , 0.25443304],
#            [0.16476408, 0.09712017, 0.8921751 , 0.5227633 ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'chair'],
#     'detection_scores': [0.9037739, 0.5778539],
#     'detection_boxes': array([[0.07368109, 0.5252264 , 0.63014686, 0.85793203],
#            [0.48125383, 0.02444214, 0.98727584, 0.25209314]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'chair'],
#     'detection_scores': [0.8221657, 0.5834814],
#     'detection_boxes': array([[0.09234282, 0.52287686, 0.9021604 , 0.8621274 ],
#            [0.47162947, 0.02166586, 0.98113286, 0.25249916]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'chair', 'person'],
#     'detection_scores': [0.86268663, 0.62412995, 0.5418856],
#     'detection_boxes': array([[0.08129537, 0.5331198 , 0.6943055 , 0.855641  ],
#            [0.48605245, 0.02362007, 0.9831725 , 0.25322568],
#            [0.1593459 , 0.09911615, 0.8859148 , 0.42770553]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'chair', 'person'],
#     'detection_scores': [0.8218909, 0.6579108, 0.50718987],
#     'detection_boxes': array([[0.09143129, 0.5243218 , 0.90076494, 0.8640033 ],
#            [0.4899471 , 0.02558505, 0.9877541 , 0.2571871 ],
#            [0.16155374, 0.09802516, 0.90443635, 0.4180261 ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'chair', 'person'],
#     'detection_scores': [0.8442241, 0.65715116, 0.5559096],
#     'detection_boxes': array([[0.07618999, 0.5342239 , 0.65460885, 0.859274  ],
#            [0.49333197, 0.02879853, 0.9877059 , 0.25463802],
#            [0.16301993, 0.09593266, 0.9141567 , 0.44209564]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'chair', 'person'],
#     'detection_scores': [0.82922924, 0.63772744, 0.587847],
#     'detection_boxes': array([[0.08420655, 0.53863806, 0.6698898 , 0.86213905],
#            [0.5011358 , 0.02694742, 0.9871564 , 0.25893098],
#            [0.17012069, 0.09728205, 0.90828633, 0.43342382]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'person', 'chair'],
#     'detection_scores': [0.80560595, 0.71329755, 0.65404004],
#     'detection_boxes': array([[0.11605269, 0.5346674 , 0.8834896 , 0.8728409 ],
#            [0.16797304, 0.09400661, 0.87002003, 0.47974807],
#            [0.5059214 , 0.02386214, 0.9896131 , 0.25520253]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'person', 'chair'],
#     'detection_scores': [0.8236766, 0.7393442, 0.68533874],
#     'detection_boxes': array([[0.10842589, 0.4997006 , 0.88990176, 0.8815407 ],
#            [0.16798112, 0.09296755, 0.8804318 , 0.449413  ],
#            [0.50437534, 0.02371526, 0.9884567 , 0.25342026]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'person', 'chair'],
#     'detection_scores': [0.818939, 0.688998, 0.68290955],
#     'detection_boxes': array([[0.1152001 , 0.47586632, 0.89416796, 0.89023554],
#            [0.16218618, 0.09438644, 0.8593812 , 0.42968524],
#            [0.50641346, 0.02297254, 0.98604035, 0.24892174]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'chair', 'person'],
#     'detection_scores': [0.85790986, 0.6743025, 0.64108396],
#     'detection_boxes': array([[0.12173498, 0.452459  , 0.8867754 , 0.8917234 ],
#            [0.5093729 , 0.03754105, 0.98084265, 0.25396168],
#            [0.15744314, 0.09128638, 0.89391947, 0.41321456]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'person', 'chair'],
#     'detection_scores': [0.80439967, 0.62962556, 0.60291386],
#     'detection_boxes': array([[0.11846814, 0.4440146 , 0.9194714 , 0.8926725 ],
#            [0.15576738, 0.09516814, 0.93284184, 0.41334412],
#            [0.5039758 , 0.04012026, 0.980967  , 0.25927174]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'chair', 'person'],
#     'detection_scores': [0.82101536, 0.6681627, 0.6212037],
#     'detection_boxes': array([[0.11556068, 0.4320615 , 0.92935216, 0.89800054],
#            [0.5157527 , 0.03300806, 0.9823209 , 0.25481188],
#            [0.1626355 , 0.09658894, 0.9465602 , 0.495921  ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'chair', 'person'],
#     'detection_scores': [0.7905346, 0.66897964, 0.6194472],
#     'detection_boxes': array([[0.10847023, 0.41804373, 0.9192078 , 0.89518785],
#            [0.5153687 , 0.03228009, 0.983181  , 0.2502427 ],
#            [0.16136077, 0.09726419, 0.93869066, 0.5104806 ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'person', 'chair'],
#     'detection_scores': [0.84429264, 0.7387865, 0.6918328],
#     'detection_boxes': array([[0.10993505, 0.42943895, 0.9461702 , 0.8943211 ],
#            [0.16165286, 0.09183502, 0.91303676, 0.44519323],
#            [0.5217356 , 0.02995951, 0.9833357 , 0.24874178]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'chair', 'person'],
#     'detection_scores': [0.83442724, 0.6926069, 0.6665132],
#     'detection_boxes': array([[0.1097244 , 0.43142784, 0.95116127, 0.89422977],
#            [0.52328455, 0.03104696, 0.98540294, 0.25077796],
#            [0.16490483, 0.09218569, 0.95068586, 0.45341617]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'chair', 'person'],
#     'detection_scores': [0.8371143, 0.6901251, 0.65835065],
#     'detection_boxes': array([[0.11340246, 0.43723312, 0.93556213, 0.89952767],
#            [0.52327275, 0.03638463, 0.98319376, 0.25347072],
#            [0.16703603, 0.09063987, 0.94825923, 0.45602638]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'person', 'chair'],
#     'detection_scores': [0.831348, 0.6778063, 0.6705357],
#     'detection_boxes': array([[0.1179786 , 0.4414683 , 0.94018006, 0.9006149 ],
#            [0.1625042 , 0.09314628, 0.9336704 , 0.42869318],
#            [0.518238  , 0.0370999 , 0.98357683, 0.25795743]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'person', 'chair'],
#     'detection_scores': [0.82961214, 0.71532935, 0.6816172],
#     'detection_boxes': array([[0.11764982, 0.44353876, 0.94125676, 0.90174925],
#            [0.16224569, 0.09249935, 0.9307733 , 0.41824678],
#            [0.52095497, 0.04389314, 0.9831821 , 0.26170063]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'person', 'chair'],
#     'detection_scores': [0.83841914, 0.7298706, 0.6599567],
#     'detection_boxes': array([[0.11814371, 0.4456821 , 0.9461602 , 0.9006434 ],
#            [0.15926743, 0.0926006 , 0.9150281 , 0.39116818],
#            [0.5173213 , 0.04555597, 0.9876084 , 0.2642352 ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'person', 'chair'],
#     'detection_scores': [0.7993853, 0.7162732, 0.6586934],
#     'detection_boxes': array([[0.11929303, 0.449654  , 0.9464933 , 0.90037537],
#            [0.16165763, 0.09009817, 0.84372324, 0.36500743],
#            [0.5136754 , 0.04168056, 0.98987466, 0.2671138 ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'person', 'chair'],
#     'detection_scores': [0.7999745, 0.7304396, 0.6632697],
#     'detection_boxes': array([[0.12209827, 0.4490198 , 0.93650407, 0.90107095],
#            [0.16172025, 0.0984983 , 0.9112406 , 0.374466  ],
#            [0.51353556, 0.04517157, 0.9877257 , 0.26595673]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'person', 'chair'],
#     'detection_scores': [0.8112711, 0.69569314, 0.6787837],
#     'detection_boxes': array([[0.12233117, 0.44307178, 0.94055223, 0.89976555],
#            [0.16669664, 0.09080727, 0.8834249 , 0.36023867],
#            [0.51459503, 0.04566079, 0.98441756, 0.26117685]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'person', 'chair'],
#     'detection_scores': [0.8324098, 0.68523866, 0.66251737],
#     'detection_boxes': array([[0.12222356, 0.442669  , 0.9346239 , 0.9000977 ],
#            [0.16843799, 0.0875694 , 0.84414244, 0.36466748],
#            [0.5122704 , 0.04469641, 0.98331827, 0.26094902]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'person', 'chair'],
#     'detection_scores': [0.8346673, 0.7248843, 0.6281081],
#     'detection_boxes': array([[0.12106004, 0.4420032 , 0.9130136 , 0.9007142 ],
#            [0.1652048 , 0.09168456, 0.8949491 , 0.38748032],
#            [0.52275133, 0.04465532, 0.97995126, 0.26809797]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'person', 'chair'],
#     'detection_scores': [0.84437007, 0.6931988, 0.63982],
#     'detection_boxes': array([[0.11607295, 0.44096482, 0.8924683 , 0.90023017],
#            [0.16554591, 0.09079219, 0.9122267 , 0.40131897],
#            [0.526892  , 0.04429249, 0.97758144, 0.26690271]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'person', 'chair'],
#     'detection_scores': [0.842995, 0.6475065, 0.6125459],
#     'detection_boxes': array([[0.11498228, 0.43701732, 0.9190222 , 0.90023434],
#            [0.16722879, 0.08721189, 0.90925705, 0.41236413],
#            [0.52701586, 0.04628811, 0.9766609 , 0.2712144 ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'chair', 'person'],
#     'detection_scores': [0.8364615, 0.62232614, 0.60820794],
#     'detection_boxes': array([[0.11954173, 0.44805112, 0.8980404 , 0.89727855],
#            [0.52528936, 0.04321688, 0.97725147, 0.2712379 ],
#            [0.16243216, 0.08794945, 0.92961526, 0.40557104]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'person', 'chair'],
#     'detection_scores': [0.79191315, 0.70433044, 0.7013142],
#     'detection_boxes': array([[0.12126523, 0.46927416, 0.92098194, 0.88805425],
#            [0.16307744, 0.09191631, 0.92328286, 0.39122754],
#            [0.51973766, 0.03668584, 0.9844157 , 0.2565456 ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'person', 'chair'],
#     'detection_scores': [0.81648624, 0.7386299, 0.6641073],
#     'detection_boxes': array([[0.11565009, 0.50503814, 0.6346438 , 0.87891185],
#            [0.16389963, 0.09242187, 0.92717063, 0.4152854 ],
#            [0.5162812 , 0.03469563, 0.98494536, 0.25969222]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'person', 'chair'],
#     'detection_scores': [0.8677177, 0.73350173, 0.6453268],
#     'detection_boxes': array([[0.10804045, 0.5155879 , 0.632875  , 0.8647696 ],
#            [0.1646901 , 0.09200473, 0.93435   , 0.40994608],
#            [0.51804876, 0.03329328, 0.9848063 , 0.2598523 ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'person', 'chair'],
#     'detection_scores': [0.76390857, 0.7248055, 0.63482296],
#     'detection_boxes': array([[0.09571013, 0.51737875, 0.60525787, 0.8534979 ],
#            [0.16202515, 0.0943273 , 0.94061285, 0.4060717 ],
#            [0.51889026, 0.03245211, 0.986742  , 0.2602851 ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'person', 'chair'],
#     'detection_scores': [0.757352, 0.6921639, 0.64306253],
#     'detection_boxes': array([[0.1063388 , 0.50420713, 0.9378763 , 0.8547207 ],
#            [0.16338798, 0.09428464, 0.9383246 , 0.40763497],
#            [0.5192346 , 0.03256437, 0.9846162 , 0.2566475 ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'person', 'chair'],
#     'detection_scores': [0.8359833, 0.707821, 0.6451994],
#     'detection_boxes': array([[0.09990495, 0.51672745, 0.9544843 , 0.8452065 ],
#            [0.16342479, 0.09209274, 0.94368607, 0.39370877],
#            [0.52058   , 0.03357223, 0.98531216, 0.25366098]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'person', 'chair'],
#     'detection_scores': [0.8411987, 0.6633676, 0.6240365],
#     'detection_boxes': array([[0.11126512, 0.51430476, 0.96174353, 0.8425474 ],
#            [0.16127962, 0.0964717 , 0.95095104, 0.4018373 ],
#            [0.5154163 , 0.03877886, 0.9863263 , 0.2568374 ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'person', 'chair'],
#     'detection_scores': [0.8400835, 0.65779316, 0.636444],
#     'detection_boxes': array([[0.10388929, 0.5113561 , 0.95885533, 0.8397809 ],
#            [0.15932247, 0.10117014, 0.9500891 , 0.4043851 ],
#            [0.5172709 , 0.03854924, 0.9856545 , 0.25708085]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person',
#      'chair',
#      'person',
#      'person'],
#     'detection_scores': [0.799064, 0.64471406, 0.6143806, 0.55434775],
#     'detection_boxes': array([[0.09950867, 0.5090719 , 0.9607223 , 0.83109194],
#            [0.5121792 , 0.03750665, 0.98555833, 0.260438  ],
#            [0.15785313, 0.10053453, 0.93707   , 0.38073757],
#            [0.07562229, 0.5170235 , 0.6281481 , 0.8317811 ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person',
#      'person',
#      'chair',
#      'person'],
#     'detection_scores': [0.74497074, 0.6947511, 0.63782614, 0.50425804],
#     'detection_boxes': array([[0.09512541, 0.51200116, 0.957327  , 0.8230647 ],
#            [0.15794575, 0.10180721, 0.9204049 , 0.37483582],
#            [0.510579  , 0.03515171, 0.9823545 , 0.25911182],
#            [0.07171029, 0.5169279 , 0.6348241 , 0.8266967 ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'person', 'chair'],
#     'detection_scores': [0.76757145, 0.70441175, 0.6458555],
#     'detection_boxes': array([[0.09793419, 0.5034052 , 0.94834346, 0.82001257],
#            [0.16031495, 0.09821549, 0.91422033, 0.37027287],
#            [0.510649  , 0.03454302, 0.9801616 , 0.26052484]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'person', 'chair'],
#     'detection_scores': [0.7597692, 0.70857, 0.6440943],
#     'detection_boxes': array([[0.09127623, 0.5053779 , 0.94983214, 0.8187536 ],
#            [0.17134553, 0.09321031, 0.8857247 , 0.35849687],
#            [0.5076587 , 0.03398395, 0.9795686 , 0.2593934 ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'person', 'chair'],
#     'detection_scores': [0.7661381, 0.74131894, 0.6659806],
#     'detection_boxes': array([[0.09385926, 0.50342745, 0.94370073, 0.8191425 ],
#            [0.1568569 , 0.09860212, 0.9137906 , 0.36212742],
#            [0.5065913 , 0.03194436, 0.98100734, 0.26171586]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person',
#      'person',
#      'person',
#      'chair'],
#     'detection_scores': [0.74140686, 0.7350788, 0.65658975, 0.65381014],
#     'detection_boxes': array([[0.15846696, 0.09805012, 0.9203204 , 0.3739665 ],
#            [0.10465637, 0.50421405, 0.9067662 , 0.8151581 ],
#            [0.06799397, 0.50999486, 0.6204227 , 0.8183595 ],
#            [0.5052078 , 0.03035603, 0.98253405, 0.25886104]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'person', 'chair'],
#     'detection_scores': [0.75253296, 0.7466255, 0.61493003],
#     'detection_boxes': array([[0.15952253, 0.0963219 , 0.9170356 , 0.37181562],
#            [0.06586096, 0.5185385 , 0.61915565, 0.81520844],
#            [0.50526625, 0.03219695, 0.9811745 , 0.25986445]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'person', 'chair'],
#     'detection_scores': [0.79935205, 0.79581076, 0.54584855],
#     'detection_boxes': array([[0.06882548, 0.52742857, 0.62138724, 0.81576246],
#            [0.16324073, 0.09403522, 0.90793866, 0.38572156],
#            [0.5124994 , 0.03096437, 0.97263294, 0.269866  ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'person', 'chair'],
#     'detection_scores': [0.8378202, 0.75034577, 0.55302685],
#     'detection_boxes': array([[0.07236359, 0.5329576 , 0.62252414, 0.8141604 ],
#            [0.16318458, 0.09638822, 0.91809994, 0.4010421 ],
#            [0.51346976, 0.03198712, 0.97233194, 0.26625144]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'person', 'chair'],
#     'detection_scores': [0.8189771, 0.764013, 0.554667],
#     'detection_boxes': array([[0.07789308, 0.53578484, 0.63204944, 0.8153908 ],
#            [0.16355985, 0.0970391 , 0.9145692 , 0.402236  ],
#            [0.5137496 , 0.03386043, 0.9783492 , 0.26047945]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'person', 'chair'],
#     'detection_scores': [0.82813317, 0.78317297, 0.65628815],
#     'detection_boxes': array([[0.07297593, 0.5257291 , 0.6311452 , 0.81128293],
#            [0.16083083, 0.10386457, 0.92903054, 0.4098724 ],
#            [0.5072594 , 0.03136757, 0.9829591 , 0.24712533]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'person', 'chair'],
#     'detection_scores': [0.80560714, 0.796846, 0.6560586],
#     'detection_boxes': array([[0.15823224, 0.10305291, 0.9220748 , 0.41155326],
#            [0.07445648, 0.516797  , 0.6240729 , 0.8100746 ],
#            [0.50598216, 0.02987996, 0.9839623 , 0.24806541]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'person', 'chair'],
#     'detection_scores': [0.8245267, 0.80620563, 0.63713735],
#     'detection_boxes': array([[0.155545  , 0.10184346, 0.92293346, 0.40502083],
#            [0.07549873, 0.5295502 , 0.63155985, 0.80816984],
#            [0.5061385 , 0.03137696, 0.98493904, 0.24786454]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person',
#      'person',
#      'chair',
#      'person'],
#     'detection_scores': [0.80855817, 0.7717537, 0.5910659, 0.5351194],
#     'detection_boxes': array([[0.15465969, 0.10089597, 0.9109705 , 0.40384385],
#            [0.1092321 , 0.52821124, 0.91597056, 0.8099992 ],
#            [0.50414336, 0.03552953, 0.98325443, 0.25062206],
#            [0.07895467, 0.5265872 , 0.61677694, 0.8059047 ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'person', 'chair'],
#     'detection_scores': [0.82268953, 0.75407296, 0.57997996],
#     'detection_boxes': array([[0.15404814, 0.10186249, 0.9288083 , 0.4064244 ],
#            [0.07687953, 0.52349746, 0.6398721 , 0.8059225 ],
#            [0.503293  , 0.0358288 , 0.9823765 , 0.24754041]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'person', 'chair'],
#     'detection_scores': [0.8174083, 0.7607596, 0.5943188],
#     'detection_boxes': array([[0.1532897 , 0.10176671, 0.9329915 , 0.41762376],
#            [0.10701442, 0.52415395, 0.91692626, 0.8076563 ],
#            [0.50449276, 0.03415038, 0.9843149 , 0.24367628]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'person', 'chair'],
#     'detection_scores': [0.817177, 0.7824947, 0.62395793],
#     'detection_boxes': array([[0.15230492, 0.10081376, 0.9334327 , 0.42309946],
#            [0.09945571, 0.52115977, 0.93047166, 0.8062781 ],
#            [0.50290453, 0.0366042 , 0.97949505, 0.2501152 ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'person', 'chair'],
#     'detection_scores': [0.79885495, 0.7949433, 0.6484071],
#     'detection_boxes': array([[0.15223649, 0.10305534, 0.9417219 , 0.425043  ],
#            [0.10220024, 0.5193548 , 0.9227977 , 0.8079946 ],
#            [0.5068403 , 0.03416898, 0.9799314 , 0.24817425]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'person', 'chair'],
#     'detection_scores': [0.79785246, 0.74442536, 0.64981645],
#     'detection_boxes': array([[0.15271872, 0.10345681, 0.9306647 , 0.42761642],
#            [0.07668614, 0.52107173, 0.6354961 , 0.8051737 ],
#            [0.50157684, 0.03234326, 0.978259  , 0.24772859]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'person', 'chair'],
#     'detection_scores': [0.80949897, 0.80179393, 0.6259506],
#     'detection_boxes': array([[0.07630578, 0.52346647, 0.63255787, 0.80605376],
#            [0.15225628, 0.10435113, 0.93526816, 0.42365262],
#            [0.5033822 , 0.03486085, 0.97562027, 0.24848947]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'person', 'chair'],
#     'detection_scores': [0.80585665, 0.8035381, 0.6086543],
#     'detection_boxes': array([[0.15289035, 0.10244066, 0.926638  , 0.4246856 ],
#            [0.07682753, 0.5196071 , 0.63099766, 0.80653423],
#            [0.50654125, 0.03483684, 0.974875  , 0.2517628 ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'person', 'chair'],
#     'detection_scores': [0.8287651, 0.7711894, 0.612698],
#     'detection_boxes': array([[0.07796168, 0.5180347 , 0.64246905, 0.807703  ],
#            [0.15468732, 0.10386106, 0.93095934, 0.4279609 ],
#            [0.5014181 , 0.03406996, 0.97600186, 0.25027177]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'person', 'chair'],
#     'detection_scores': [0.8497852, 0.80368155, 0.6288625],
#     'detection_boxes': array([[0.07632902, 0.519561  , 0.6409991 , 0.80665606],
#            [0.1549739 , 0.10274078, 0.9041182 , 0.4362325 ],
#            [0.50780314, 0.03316285, 0.9654736 , 0.2475913 ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'person', 'chair'],
#     'detection_scores': [0.88221526, 0.800699, 0.5541891],
#     'detection_boxes': array([[0.0747636 , 0.51898557, 0.63660693, 0.80772763],
#            [0.15738022, 0.10257047, 0.9138447 , 0.4389413 ],
#            [0.5037239 , 0.03588337, 0.96397287, 0.24985954]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'person', 'chair'],
#     'detection_scores': [0.82087374, 0.7902326, 0.53531706],
#     'detection_boxes': array([[0.07864815, 0.5201376 , 0.6334668 , 0.8100143 ],
#            [0.15805367, 0.10175654, 0.91626716, 0.43789622],
#            [0.509167  , 0.0365181 , 0.9650679 , 0.25858334]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'person', 'chair'],
#     'detection_scores': [0.8425126, 0.7698871, 0.5697215],
#     'detection_boxes': array([[0.07312891, 0.5202665 , 0.63724303, 0.81223446],
#            [0.15699354, 0.10439301, 0.9267956 , 0.4405418 ],
#            [0.50781894, 0.03525355, 0.9778429 , 0.2489807 ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'person', 'chair'],
#     'detection_scores': [0.84830505, 0.76938754, 0.5761625],
#     'detection_boxes': array([[0.073713  , 0.51975155, 0.6354238 , 0.8123474 ],
#            [0.15776017, 0.10373437, 0.9254137 , 0.43552148],
#            [0.5065157 , 0.03698847, 0.9657255 , 0.25098842]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'person', 'chair'],
#     'detection_scores': [0.801051, 0.7693732, 0.5757409],
#     'detection_boxes': array([[0.07306311, 0.52293754, 0.633989  , 0.8107916 ],
#            [0.15650192, 0.10428557, 0.9269072 , 0.43108246],
#            [0.5084656 , 0.03574913, 0.975398  , 0.24959186]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'person', 'chair'],
#     'detection_scores': [0.9200983, 0.7874629, 0.6442729],
#     'detection_boxes': array([[0.07458097, 0.5132901 , 0.63225573, 0.8148976 ],
#            [0.15244162, 0.10345246, 0.8945056 , 0.4263978 ],
#            [0.51374924, 0.03033685, 0.97345364, 0.26196933]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'person', 'chair'],
#     'detection_scores': [0.912107, 0.7855276, 0.63982165],
#     'detection_boxes': array([[0.07525665, 0.5143349 , 0.6321343 , 0.81589925],
#            [0.15285963, 0.10252734, 0.8946528 , 0.42405248],
#            [0.51228565, 0.03084198, 0.9760787 , 0.25363433]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person',
#      'person',
#      'person',
#      'chair'],
#     'detection_scores': [0.898714, 0.7785856, 0.76277244, 0.602714],
#     'detection_boxes': array([[0.07979792, 0.515403  , 0.63077885, 0.81598717],
#            [0.15183112, 0.10308255, 0.8938954 , 0.42790848],
#            [0.13060555, 0.5087083 , 0.8930713 , 0.82523626],
#            [0.50917965, 0.03092796, 0.9713711 , 0.25467348]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'person', 'chair'],
#     'detection_scores': [0.9241975, 0.76577646, 0.6178822],
#     'detection_boxes': array([[0.07537642, 0.5228542 , 0.6267507 , 0.8192742 ],
#            [0.1510478 , 0.10460359, 0.8969668 , 0.42482895],
#            [0.5080083 , 0.0248604 , 0.9766317 , 0.25335884]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'person', 'chair'],
#     'detection_scores': [0.8864909, 0.7855152, 0.5963919],
#     'detection_boxes': array([[0.07146591, 0.5205255 , 0.6300151 , 0.8186987 ],
#            [0.14974588, 0.10602003, 0.89248973, 0.42333466],
#            [0.50444204, 0.02438564, 0.97738296, 0.25346914]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'person', 'chair'],
#     'detection_scores': [0.88563675, 0.75859976, 0.6113777],
#     'detection_boxes': array([[0.0729458 , 0.51954645, 0.63374484, 0.82216626],
#            [0.15330568, 0.1039719 , 0.88145554, 0.42991984],
#            [0.513674  , 0.02636234, 0.97078085, 0.2609242 ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'person', 'chair'],
#     'detection_scores': [0.8954919, 0.75446475, 0.60923153],
#     'detection_boxes': array([[0.07413831, 0.52222097, 0.62916577, 0.82232225],
#            [0.1527135 , 0.10536405, 0.88488126, 0.43654963],
#            [0.5080228 , 0.02857198, 0.97443724, 0.2561736 ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'person', 'chair'],
#     'detection_scores': [0.90487087, 0.75670505, 0.6132701],
#     'detection_boxes': array([[0.07549068, 0.5281173 , 0.6208503 , 0.82132435],
#            [0.15432248, 0.1069245 , 0.8881819 , 0.4455445 ],
#            [0.50896156, 0.02773804, 0.9719434 , 0.25526485]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'person', 'chair'],
#     'detection_scores': [0.89057165, 0.77465504, 0.6160919],
#     'detection_boxes': array([[0.07201773, 0.52806413, 0.61602193, 0.8212843 ],
#            [0.15170625, 0.10574935, 0.88248086, 0.4311142 ],
#            [0.51614326, 0.02889599, 0.97011334, 0.26396585]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'person', 'chair'],
#     'detection_scores': [0.9030108, 0.78521615, 0.61215544],
#     'detection_boxes': array([[0.07784206, 0.52950364, 0.6204498 , 0.81912476],
#            [0.15090019, 0.10720889, 0.89193374, 0.4332916 ],
#            [0.5107748 , 0.02961174, 0.9718129 , 0.25766593]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'person', 'chair'],
#     'detection_scores': [0.8794132, 0.80130583, 0.64735454],
#     'detection_boxes': array([[0.07172617, 0.53958917, 0.6075666 , 0.82437074],
#            [0.15167964, 0.10561457, 0.8593073 , 0.4329321 ],
#            [0.5165242 , 0.02671491, 0.97933924, 0.25838876]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'person', 'chair'],
#     'detection_scores': [0.8673796, 0.80486435, 0.6557712],
#     'detection_boxes': array([[0.06992003, 0.53813255, 0.60630774, 0.82492423],
#            [0.15092903, 0.10597691, 0.86687833, 0.43292758],
#            [0.5207435 , 0.02545426, 0.9758396 , 0.26400566]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'person', 'chair'],
#     'detection_scores': [0.84558064, 0.7960069, 0.6639311],
#     'detection_boxes': array([[0.0770154 , 0.5374739 , 0.6142731 , 0.81920934],
#            [0.15090156, 0.10659996, 0.8790828 , 0.43139747],
#            [0.5207597 , 0.02562849, 0.97820556, 0.2642153 ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'person', 'chair'],
#     'detection_scores': [0.8048441, 0.7865424, 0.6459036],
#     'detection_boxes': array([[0.11100709, 0.56452346, 0.6163037 , 0.82831526],
#            [0.15033343, 0.10596901, 0.88774407, 0.4301116 ],
#            [0.5223738 , 0.02656548, 0.97661376, 0.26411146]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'person', 'chair'],
#     'detection_scores': [0.81575966, 0.79654443, 0.65553564],
#     'detection_boxes': array([[0.10734847, 0.5608675 , 0.611904  , 0.83015186],
#            [0.15101206, 0.10696165, 0.87203896, 0.43351018],
#            [0.5200312 , 0.02717108, 0.9742912 , 0.26640433]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'person', 'chair'],
#     'detection_scores': [0.85235596, 0.7843812, 0.6357259],
#     'detection_boxes': array([[0.07239848, 0.5393729 , 0.60809773, 0.82036614],
#            [0.15184742, 0.10672075, 0.88469535, 0.44380897],
#            [0.52059317, 0.02664988, 0.974054  , 0.26352802]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'person', 'chair'],
#     'detection_scores': [0.8788186, 0.7889595, 0.57052284],
#     'detection_boxes': array([[0.0809679 , 0.5330387 , 0.6103112 , 0.8197728 ],
#            [0.15237254, 0.10900787, 0.8634239 , 0.43960854],
#            [0.5139359 , 0.02598034, 0.97192216, 0.26716208]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'person', 'chair'],
#     'detection_scores': [0.9118309, 0.7843672, 0.5921397],
#     'detection_boxes': array([[0.07231495, 0.5303602 , 0.60983825, 0.8193922 ],
#            [0.15293264, 0.10809387, 0.87277186, 0.43573922],
#            [0.51438826, 0.02447485, 0.97270125, 0.26730624]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person',
#      'person',
#      'person',
#      'chair'],
#     'detection_scores': [0.8288645, 0.7889464, 0.64495796, 0.6312505],
#     'detection_boxes': array([[0.07509136, 0.5339572 , 0.61694384, 0.8211667 ],
#            [0.11593097, 0.528074  , 0.8695201 , 0.8377856 ],
#            [0.15445161, 0.10858279, 0.9078065 , 0.45382702],
#            [0.51835304, 0.03401093, 0.9776687 , 0.26387143]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person',
#      'person',
#      'person',
#      'chair'],
#     'detection_scores': [0.8037979, 0.76638764, 0.656431, 0.6361046],
#     'detection_boxes': array([[0.11858264, 0.5280157 , 0.8621881 , 0.83749336],
#            [0.07349944, 0.5328808 , 0.6165973 , 0.82060575],
#            [0.15469775, 0.10869081, 0.8995755 , 0.45310515],
#            [0.5185686 , 0.03088883, 0.97762674, 0.26365364]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person',
#      'person',
#      'person',
#      'chair'],
#     'detection_scores': [0.77792543, 0.7467534, 0.6686405, 0.6446783],
#     'detection_boxes': array([[0.11720851, 0.5361797 , 0.8573613 , 0.8369488 ],
#            [0.1086641 , 0.562556  , 0.62426114, 0.8262328 ],
#            [0.15353766, 0.10774612, 0.9026624 , 0.45310175],
#            [0.51700014, 0.02791879, 0.9780008 , 0.26258984]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person',
#      'person',
#      'person',
#      'chair'],
#     'detection_scores': [0.81906956, 0.69279605, 0.6605835, 0.6172081],
#     'detection_boxes': array([[0.11768264, 0.52760124, 0.8758475 , 0.8379874 ],
#            [0.15344435, 0.10782737, 0.8864905 , 0.4485497 ],
#            [0.10404873, 0.55559784, 0.6272763 , 0.8288252 ],
#            [0.5105821 , 0.02922772, 0.97009337, 0.26623136]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person',
#      'person',
#      'person',
#      'chair'],
#     'detection_scores': [0.8154336, 0.67340344, 0.65963113, 0.6116034],
#     'detection_boxes': array([[0.12190446, 0.52394545, 0.89055824, 0.83929443],
#            [0.152138  , 0.10736531, 0.90143013, 0.43977308],
#            [0.07507548, 0.53031266, 0.6251571 , 0.8238368 ],
#            [0.51137525, 0.03035838, 0.97206455, 0.2662035 ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person',
#      'person',
#      'person',
#      'chair'],
#     'detection_scores': [0.7711163, 0.7641968, 0.7414569, 0.55954397],
#     'detection_boxes': array([[0.11955705, 0.53287715, 0.8524926 , 0.83786124],
#            [0.06932026, 0.5337126 , 0.60799384, 0.8220377 ],
#            [0.15171078, 0.10772102, 0.86902356, 0.43746424],
#            [0.5107616 , 0.03008811, 0.9693879 , 0.2707644 ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'person', 'chair'],
#     'detection_scores': [0.8356392, 0.6833951, 0.5609521],
#     'detection_boxes': array([[0.07023567, 0.531405  , 0.6085678 , 0.8250929 ],
#            [0.1557791 , 0.10856172, 0.8853514 , 0.44469425],
#            [0.5160595 , 0.02826564, 0.9743918 , 0.2720921 ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'person', 'chair'],
#     'detection_scores': [0.8377354, 0.66885287, 0.545119],
#     'detection_boxes': array([[0.06950504, 0.5331321 , 0.6091041 , 0.8243525 ],
#            [0.15543014, 0.10921887, 0.89339775, 0.4495767 ],
#            [0.5157264 , 0.02720869, 0.9764791 , 0.2717218 ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'person', 'chair'],
#     'detection_scores': [0.85330206, 0.67413265, 0.5661861],
#     'detection_boxes': array([[0.07020667, 0.5330244 , 0.609378  , 0.8249368 ],
#            [0.15390366, 0.10841808, 0.90615577, 0.44110796],
#            [0.519103  , 0.02828739, 0.97514695, 0.27573726]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'person', 'chair'],
#     'detection_scores': [0.86177504, 0.6719829, 0.5719673],
#     'detection_boxes': array([[0.07102442, 0.53188586, 0.60972524, 0.82437265],
#            [0.15396336, 0.10799746, 0.90612614, 0.4417091 ],
#            [0.5176774 , 0.02690324, 0.9728172 , 0.27689174]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'person', 'chair'],
#     'detection_scores': [0.808285, 0.7177719, 0.5740477],
#     'detection_boxes': array([[0.09995681, 0.55710495, 0.6124044 , 0.8317107 ],
#            [0.15555519, 0.10707805, 0.8919099 , 0.44175544],
#            [0.5181216 , 0.02859981, 0.9651309 , 0.2739684 ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'person', 'chair'],
#     'detection_scores': [0.8153673, 0.7062476, 0.5709107],
#     'detection_boxes': array([[0.10137683, 0.55681884, 0.61389303, 0.8318236 ],
#            [0.15593243, 0.10780799, 0.89889336, 0.44851822],
#            [0.5192351 , 0.02813072, 0.96447116, 0.2735328 ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'person', 'chair'],
#     'detection_scores': [0.83805627, 0.62233204, 0.5548368],
#     'detection_boxes': array([[0.09539935, 0.558885  , 0.61506474, 0.83193374],
#            [0.1571579 , 0.10957909, 0.92079616, 0.4627673 ],
#            [0.5172071 , 0.02751693, 0.97045475, 0.2793409 ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'person', 'chair'],
#     'detection_scores': [0.8540732, 0.61376405, 0.5766396],
#     'detection_boxes': array([[0.09503672, 0.5591393 , 0.6189053 , 0.8324674 ],
#            [0.15602112, 0.10969977, 0.9276713 , 0.47121757],
#            [0.5165136 , 0.02614224, 0.96858263, 0.27782986]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'person', 'chair'],
#     'detection_scores': [0.8420751, 0.6163257, 0.5654235],
#     'detection_boxes': array([[0.09262216, 0.5563978 , 0.6195881 , 0.83232975],
#            [0.15535012, 0.10913984, 0.92940795, 0.46815842],
#            [0.51725364, 0.02417099, 0.96771014, 0.27602184]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'person', 'chair'],
#     'detection_scores': [0.844842, 0.6115678, 0.5627947],
#     'detection_boxes': array([[0.09625414, 0.5592913 , 0.6208432 , 0.83250207],
#            [0.15557769, 0.11010982, 0.92790496, 0.46517968],
#            [0.5161585 , 0.02451029, 0.96535283, 0.27436754]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'person', 'chair'],
#     'detection_scores': [0.8281677, 0.6493843, 0.5485111],
#     'detection_boxes': array([[0.09750986, 0.55738306, 0.6236777 , 0.8326359 ],
#            [0.15852845, 0.1087614 , 0.91504025, 0.4617842 ],
#            [0.5104129 , 0.02955583, 0.963703  , 0.27464166]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'person', 'chair'],
#     'detection_scores': [0.82990223, 0.6483527, 0.5112767],
#     'detection_boxes': array([[0.09691414, 0.56171423, 0.6242758 , 0.83229727],
#            [0.15809673, 0.10820809, 0.91918176, 0.46094456],
#            [0.5111493 , 0.02874181, 0.9665892 , 0.2760353 ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person',
#      'person',
#      'person',
#      'chair'],
#     'detection_scores': [0.80768, 0.8063846, 0.8028756, 0.60744053],
#     'detection_boxes': array([[0.12042853, 0.53911006, 0.8748853 , 0.8467463 ],
#            [0.11237955, 0.56281966, 0.62488   , 0.83396035],
#            [0.15417227, 0.1108422 , 0.8770298 , 0.44667688],
#            [0.5188061 , 0.03005593, 0.96431553, 0.27027532]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person',
#      'person',
#      'person',
#      'chair'],
#     'detection_scores': [0.8337968, 0.78324753, 0.7766833, 0.566986],
#     'detection_boxes': array([[0.11116201, 0.5625969 , 0.6240298 , 0.8335471 ],
#            [0.1218971 , 0.53952783, 0.8588124 , 0.84539086],
#            [0.15457651, 0.10999927, 0.87779975, 0.4355031 ],
#            [0.51534677, 0.02945811, 0.96011233, 0.27308172]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person',
#      'person',
#      'person',
#      'chair'],
#     'detection_scores': [0.826089, 0.7959185, 0.73203975, 0.5479685],
#     'detection_boxes': array([[0.11210498, 0.5640336 , 0.6244397 , 0.83368516],
#            [0.12262762, 0.5414692 , 0.86337376, 0.84581673],
#            [0.15446803, 0.10944864, 0.8769367 , 0.43268898],
#            [0.5174542 , 0.02853425, 0.959053  , 0.26707506]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'person', 'chair'],
#     'detection_scores': [0.84862334, 0.69227135, 0.6094878],
#     'detection_boxes': array([[0.11386862, 0.5619757 , 0.62675726, 0.8341093 ],
#            [0.15804833, 0.11272794, 0.89446265, 0.455392  ],
#            [0.5181795 , 0.02855964, 0.9748753 , 0.25617474]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'person', 'chair'],
#     'detection_scores': [0.86191565, 0.6185906, 0.5427222],
#     'detection_boxes': array([[0.11201942, 0.5646992 , 0.6255629 , 0.8345343 ],
#            [0.1566771 , 0.11408754, 0.87380254, 0.43070042],
#            [0.51107955, 0.0270314 , 0.9727937 , 0.2548852 ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'person', 'chair'],
#     'detection_scores': [0.85604846, 0.66432184, 0.5439549],
#     'detection_boxes': array([[0.1126352 , 0.56399274, 0.6254644 , 0.8342978 ],
#            [0.1569373 , 0.11175899, 0.8534104 , 0.39424878],
#            [0.5089723 , 0.02686509, 0.97399545, 0.2586265 ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'person', 'chair'],
#     'detection_scores': [0.8365106, 0.6221155, 0.5434113],
#     'detection_boxes': array([[0.11244965, 0.5641628 , 0.6284178 , 0.83492583],
#            [0.15589133, 0.10846272, 0.8839865 , 0.40201113],
#            [0.5062587 , 0.02908821, 0.9714775 , 0.25758475]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person', 'chair', 'person'],
#     'detection_scores': [0.8274806, 0.6419434, 0.53044075],
#     'detection_boxes': array([[0.11435378, 0.56301296, 0.6295024 , 0.8352765 ],
#            [0.5126476 , 0.02974804, 0.9723493 , 0.2600081 ],
#            [0.15679449, 0.11174056, 0.87567776, 0.4069073 ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person',
#      'person',
#      'person',
#      'chair'],
#     'detection_scores': [0.7972671, 0.68092775, 0.66462827, 0.59210193],
#     'detection_boxes': array([[0.12263393, 0.5419222 , 0.8717185 , 0.84490395],
#            [0.15812215, 0.11753301, 0.86617863, 0.45252174],
#            [0.07936019, 0.53679353, 0.62078625, 0.8329064 ],
#            [0.5117665 , 0.02892739, 0.96437734, 0.2657972 ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person',
#      'person',
#      'person',
#      'chair'],
#     'detection_scores': [0.8073783, 0.6951533, 0.693728, 0.561],
#     'detection_boxes': array([[0.13342449, 0.5485915 , 0.89269495, 0.84808683],
#            [0.16064009, 0.11907984, 0.84610164, 0.46688414],
#            [0.12160417, 0.56753933, 0.6425853 , 0.8386873 ],
#            [0.50856614, 0.02945202, 0.9493555 , 0.26969618]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person',
#      'person',
#      'chair',
#      'person'],
#     'detection_scores': [0.8030242, 0.79707843, 0.5359944, 0.50758284],
#     'detection_boxes': array([[0.13165751, 0.55152994, 0.8935034 , 0.8472225 ],
#            [0.15964687, 0.11837606, 0.847702  , 0.45241624],
#            [0.51416576, 0.02913383, 0.9465883 , 0.26813203],
#            [0.08451575, 0.5382391 , 0.6269787 , 0.8385751 ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person',
#      'person',
#      'person',
#      'chair'],
#     'detection_scores': [0.79019326, 0.7703161, 0.54317707, 0.53214973],
#     'detection_boxes': array([[0.13096061, 0.5530323 , 0.8876916 , 0.84830165],
#            [0.15809599, 0.11791393, 0.8476958 , 0.44504914],
#            [0.0819127 , 0.54105055, 0.61545384, 0.8385607 ],
#            [0.51486015, 0.03076892, 0.9426936 , 0.2683373 ]], dtype=float32)}},
# ...
#     'detection_scores': [0.7234163],
#     'detection_boxes': array([[0.10184908, 0.00990984, 0.99531615, 0.9079493 ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person'],
#     'detection_scores': [0.7295842],
#     'detection_boxes': array([[0.11149132, 0.00901327, 0.99566126, 0.9042076 ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person'],
#     'detection_scores': [0.7423011],
#     'detection_boxes': array([[0.10050315, 0.00921533, 0.99658984, 0.90510523]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person'],
#     'detection_scores': [0.6901185],
#     'detection_boxes': array([[0.10385516, 0.00540188, 0.9955063 , 0.90648043]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person'],
#     'detection_scores': [0.7035152],
#     'detection_boxes': array([[0.10009351, 0.01088798, 0.9952036 , 0.9053087 ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person'],
#     'detection_scores': [0.6983557],
#     'detection_boxes': array([[0.08757976, 0.01509306, 0.9950346 , 0.91461575]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person'],
#     'detection_scores': [0.7037031],
#     'detection_boxes': array([[0.07373857, 0.02786261, 0.9954295 , 0.9164939 ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person'],
#     'detection_scores': [0.70753556],
#     'detection_boxes': array([[0.07931572, 0.02913013, 0.9955327 , 0.91268516]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person'],
#     'detection_scores': [0.7321955],
#     'detection_boxes': array([[0.08513409, 0.04232636, 0.9962022 , 0.9106386 ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person'],
#     'detection_scores': [0.7182357],
#     'detection_boxes': array([[0.07741174, 0.04018116, 0.9954641 , 0.9145621 ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person'],
#     'detection_scores': [0.71357065],
#     'detection_boxes': array([[0.06958821, 0.05166346, 0.99638116, 0.91723573]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person'],
#     'detection_scores': [0.70757985],
#     'detection_boxes': array([[0.06692189, 0.05334163, 0.99600416, 0.9119584 ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person'],
#     'detection_scores': [0.7376372],
#     'detection_boxes': array([[0.06430182, 0.05923533, 0.99573064, 0.91728216]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person'],
#     'detection_scores': [0.7494253],
#     'detection_boxes': array([[0.05974314, 0.06799608, 0.99466383, 0.9179992 ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person'],
#     'detection_scores': [0.743243],
#     'detection_boxes': array([[0.05978805, 0.07370812, 0.9945324 , 0.9176241 ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person'],
#     'detection_scores': [0.7462906],
#     'detection_boxes': array([[0.06012025, 0.07761276, 0.9947276 , 0.92159164]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person'],
#     'detection_scores': [0.7364899],
#     'detection_boxes': array([[0.05807304, 0.07777667, 0.9947505 , 0.9191292 ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person'],
#     'detection_scores': [0.7265272],
#     'detection_boxes': array([[0.05551326, 0.07918879, 0.9949889 , 0.9262214 ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person'],
#     'detection_scores': [0.7305133],
#     'detection_boxes': array([[0.05518714, 0.07988131, 0.99461544, 0.92596734]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person'],
#     'detection_scores': [0.7301507],
#     'detection_boxes': array([[0.0520868 , 0.08566061, 0.99464583, 0.92620814]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person'],
#     'detection_scores': [0.7139745],
#     'detection_boxes': array([[0.05622524, 0.08456928, 0.9945877 , 0.92472726]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person'],
#     'detection_scores': [0.7326467],
#     'detection_boxes': array([[0.05915555, 0.08982423, 0.99463797, 0.9262804 ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person'],
#     'detection_scores': [0.71748596],
#     'detection_boxes': array([[0.05942503, 0.08862129, 0.9946307 , 0.9251082 ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person'],
#     'detection_scores': [0.71984714],
#     'detection_boxes': array([[0.05589157, 0.08466721, 0.99440414, 0.92235076]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person'],
#     'detection_scores': [0.7266417],
#     'detection_boxes': array([[0.06196547, 0.07983863, 0.9946382 , 0.91123146]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person'],
#     'detection_scores': [0.69882005],
#     'detection_boxes': array([[0.05865255, 0.08465025, 0.9962876 , 0.9457501 ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person'],
#     'detection_scores': [0.6885878],
#     'detection_boxes': array([[0.06686026, 0.08037797, 0.99481696, 0.9259527 ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person'],
#     'detection_scores': [0.71612287],
#     'detection_boxes': array([[0.06400833, 0.08254129, 0.99383473, 0.85348976]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person'],
#     'detection_scores': [0.73632646],
#     'detection_boxes': array([[0.07016596, 0.08118704, 0.99450517, 0.8189348 ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person'],
#     'detection_scores': [0.74627423],
#     'detection_boxes': array([[0.06081733, 0.08874935, 0.99535143, 0.8059197 ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person'],
#     'detection_scores': [0.7217387],
#     'detection_boxes': array([[0.06556454, 0.08389449, 0.99434805, 0.8741149 ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person'],
#     'detection_scores': [0.7148144],
#     'detection_boxes': array([[0.06694645, 0.08159658, 0.994868  , 0.91131234]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person'],
#     'detection_scores': [0.7132586],
#     'detection_boxes': array([[0.06909129, 0.08213076, 0.9946711 , 0.9187412 ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person'],
#     'detection_scores': [0.7146501],
#     'detection_boxes': array([[0.06732163, 0.08431453, 0.9946526 , 0.91534257]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person'],
#     'detection_scores': [0.700583],
#     'detection_boxes': array([[0.06973755, 0.08687127, 0.9950615 , 0.92286503]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person'],
#     'detection_scores': [0.702387],
#     'detection_boxes': array([[0.06975746, 0.08662608, 0.99519587, 0.9222294 ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person'],
#     'detection_scores': [0.7190619],
#     'detection_boxes': array([[0.0669058 , 0.08726016, 0.9954478 , 0.9275632 ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person'],
#     'detection_scores': [0.71404016],
#     'detection_boxes': array([[0.07377347, 0.0875155 , 0.9955927 , 0.9270009 ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person'],
#     'detection_scores': [0.704773],
#     'detection_boxes': array([[0.07421553, 0.08665678, 0.9952276 , 0.92653155]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person'],
#     'detection_scores': [0.74399686],
#     'detection_boxes': array([[0.07506275, 0.08556518, 0.99510515, 0.9220872 ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person'],
#     'detection_scores': [0.7394495],
#     'detection_boxes': array([[0.07734266, 0.08812329, 0.9953276 , 0.92413545]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person'],
#     'detection_scores': [0.74765843],
#     'detection_boxes': array([[0.07985774, 0.08919746, 0.9956614 , 0.9251061 ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person'],
#     'detection_scores': [0.7386352],
#     'detection_boxes': array([[0.07996789, 0.08897886, 0.994964  , 0.92238   ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person'],
#     'detection_scores': [0.7263853],
#     'detection_boxes': array([[0.0866119 , 0.08422917, 0.9959091 , 0.921271  ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person'],
#     'detection_scores': [0.72936505],
#     'detection_boxes': array([[0.08645424, 0.08348125, 0.9964082 , 0.921022  ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person'],
#     'detection_scores': [0.72853845],
#     'detection_boxes': array([[0.08135039, 0.0839574 , 0.99556416, 0.9211253 ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person'],
#     'detection_scores': [0.7294848],
#     'detection_boxes': array([[0.08287245, 0.08274174, 0.9953758 , 0.9209151 ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person'],
#     'detection_scores': [0.7294933],
#     'detection_boxes': array([[0.08033627, 0.08277637, 0.9954645 , 0.91911393]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person'],
#     'detection_scores': [0.70483255],
#     'detection_boxes': array([[0.07755873, 0.0843403 , 0.9948633 , 0.9195695 ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person'],
#     'detection_scores': [0.711956],
#     'detection_boxes': array([[0.07651317, 0.08382773, 0.99504817, 0.9201665 ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person'],
#     'detection_scores': [0.7173181],
#     'detection_boxes': array([[0.07854816, 0.08422375, 0.9951818 , 0.9191818 ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person'],
#     'detection_scores': [0.7232938],
#     'detection_boxes': array([[0.08032137, 0.08456925, 0.9956227 , 0.92333186]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person'],
#     'detection_scores': [0.71105945],
#     'detection_boxes': array([[0.07854602, 0.08319002, 0.9952544 , 0.9230214 ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person'],
#     'detection_scores': [0.72030574],
#     'detection_boxes': array([[0.07895774, 0.08424369, 0.99531084, 0.9219179 ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person'],
#     'detection_scores': [0.72555745],
#     'detection_boxes': array([[0.08207279, 0.08284244, 0.9943562 , 0.91859734]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person'],
#     'detection_scores': [0.6998755],
#     'detection_boxes': array([[0.08138266, 0.08740878, 0.99909973, 0.9074763 ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person'],
#     'detection_scores': [0.7134346],
#     'detection_boxes': array([[0.07146302, 0.08470395, 0.9946519 , 0.9206221 ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person'],
#     'detection_scores': [0.7216689],
#     'detection_boxes': array([[0.07481682, 0.08312321, 0.99530673, 0.9262841 ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person'],
#     'detection_scores': [0.71771514],
#     'detection_boxes': array([[0.06704512, 0.07568711, 1.        , 0.9178044 ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person'],
#     'detection_scores': [0.70328456],
#     'detection_boxes': array([[0.07354015, 0.08956406, 0.994497  , 0.92317486]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person'],
#     'detection_scores': [0.69832027],
#     'detection_boxes': array([[0.06810442, 0.07889828, 1.        , 0.9140271 ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person'],
#     'detection_scores': [0.71605796],
#     'detection_boxes': array([[0.06102929, 0.07829621, 1.        , 0.9118185 ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person'],
#     'detection_scores': [0.7128311],
#     'detection_boxes': array([[0.06858885, 0.08582258, 0.9948833 , 0.92714787]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person'],
#     'detection_scores': [0.71367604],
#     'detection_boxes': array([[0.06308147, 0.07680362, 1.        , 0.9191133 ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person'],
#     'detection_scores': [0.72743076],
#     'detection_boxes': array([[0.06280079, 0.07840201, 1.        , 0.9134475 ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person'],
#     'detection_scores': [0.722558],
#     'detection_boxes': array([[0.0657464 , 0.0837135 , 0.99515533, 0.9262357 ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person'],
#     'detection_scores': [0.73569155],
#     'detection_boxes': array([[0.06893429, 0.07647446, 1.        , 0.9123249 ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person'],
#     'detection_scores': [0.7290408],
#     'detection_boxes': array([[0.0852432 , 0.08568162, 0.99534476, 0.92419106]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person'],
#     'detection_scores': [0.72973794],
#     'detection_boxes': array([[0.08035445, 0.07640263, 1.        , 0.9177555 ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person'],
#     'detection_scores': [0.7384701],
#     'detection_boxes': array([[0.0819177 , 0.07640231, 1.        , 0.9232735 ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person'],
#     'detection_scores': [0.73540026],
#     'detection_boxes': array([[0.08212408, 0.07615837, 1.        , 0.9163604 ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person'],
#     'detection_scores': [0.7453146],
#     'detection_boxes': array([[0.08411252, 0.07767653, 1.        , 0.9078156 ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person'],
#     'detection_scores': [0.73114103],
#     'detection_boxes': array([[0.08427778, 0.07878757, 1.        , 0.90339446]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person'],
#     'detection_scores': [0.7236342],
#     'detection_boxes': array([[0.09865505, 0.08195263, 0.99697036, 0.91212165]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person'],
#     'detection_scores': [0.7477008],
#     'detection_boxes': array([[0.10299873, 0.081902  , 0.99704254, 0.9117985 ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person'],
#     'detection_scores': [0.7607378],
#     'detection_boxes': array([[0.10900864, 0.08347428, 0.9970343 , 0.90766644]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person'],
#     'detection_scores': [0.75974023],
#     'detection_boxes': array([[0.10788065, 0.0849199 , 0.99701995, 0.9090569 ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person'],
#     'detection_scores': [0.7601498],
#     'detection_boxes': array([[0.08977753, 0.07992244, 1.        , 0.90098053]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person'],
#     'detection_scores': [0.7716567],
#     'detection_boxes': array([[0.10806131, 0.08491343, 0.99687195, 0.91192895]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person'],
#     'detection_scores': [0.7646575],
#     'detection_boxes': array([[0.1117458 , 0.08236712, 0.99714327, 0.9095718 ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person'],
#     'detection_scores': [0.7683734],
#     'detection_boxes': array([[0.11022189, 0.08200395, 0.99728   , 0.9100623 ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person'],
#     'detection_scores': [0.76802397],
#     'detection_boxes': array([[0.111233  , 0.07993096, 0.9973756 , 0.90949833]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person'],
#     'detection_scores': [0.74969304],
#     'detection_boxes': array([[0.11573187, 0.0778521 , 0.99799263, 0.9113455 ]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person'],
#     'detection_scores': [0.76842505],
#     'detection_boxes': array([[0.11554158, 0.07742625, 0.9982891 , 0.91104716]], dtype=float32)}},
#   {'annotations': {'detection_classes': ['person'],
#     'detection_scores': [0.7784155],
#     'detection_boxes': array([[0.11315963, 0.07433656, 0.99805355, 0.9102638 ]], dtype=float32)}},
#   ...]}

# %%
start, end
# Out:
# (0, 33275)

# %%
def get_key_from_batch_with_frame_nos(batch, start, category_index):
    '''
    Returns the key frames from the given batch of frames
    '''
    # Getting the required information for each frame
    ## Getting all the annotations with more than 0.6 confidence.
    information = []
    for frame in batch:
        _information = []
        for cat, bbox, score in zip(
            frame['annotations']['detection_classes'],
            frame['annotations']['detection_boxes'],
            frame['annotations']['detection_scores']
        ):
                ## 1. Only bboxes
                # something = []
                ## 2. Bboxes and class
                if score > 0.5:

                    something = [get_index_from_category(cat, category_index), score]

                    for box in bbox:
                        something.append(box)

                    _information.append(something)
        information.append(_information)

    information = [temp for temp in information if temp]
    if not information:
        return None, None
    max_objs = max([len(information[i]) for i in range(len(information))])

    clustering_data = []
    for i in range(max_objs):
        _data = []
        for j in range(len(information)):
            if len(information[j]) > i:
                _data.append(information[j][i])
        clustering_data.append(_data)

    # The above output implies, we can divide these frame
    # into a max of 4 frames (considering the lowest last object occurance)
    FRAMES_THRESHOLD = 2
    clustering_data_prediction = []
    for i in range(len(clustering_data)):
        if len(clustering_data[i]) >= FRAMES_THRESHOLD:
            kmeans = KMeans(n_clusters=FRAMES_THRESHOLD, random_state=69).fit(clustering_data[i])
            clustering_data_prediction.append(kmeans.labels_)

    indx = len(clustering_data)
    for i in range(len(clustering_data)):
        if len(clustering_data[i]) < FRAMES_THRESHOLD:
            indx = i
            break

    data = []
    for frame_nos, info in enumerate(information):
        for inf in info:
            pred_index, index = search(clustering_data[:indx], inf)
            if not pred_index and not index:
                # The case of last three things
                pred_index, index = search(clustering_data, inf)
                something = [start+frame_nos]+inf+[index]
                data.append(something)
            else:
                cluster = clustering_data_prediction[pred_index][index]
                something = [start+frame_nos]+inf+[cluster]
                data.append(something)

    df = pd.DataFrame(data, columns=[
        "frame_nos", "category", "score",
        "bbox1", "bbox2", "bbox3", "bbox4", "cluster"
    ])
    df['avg_cluster'] = None

    for frame in df.frame_nos:
        df.loc[df.frame_nos == frame, "avg_cluster"] = Counter(
            df[df.frame_nos == frame].cluster.values
        ).most_common()[::-1][-1][0]

    frame_vecs = []
    fnos = []
    for cluster in range(FRAMES_THRESHOLD):
        try:
            frame_vecs.append(
#             df[df.avg_cluster == cluster].sort_values("score").frame_nos.values[-1]
                # df[df.avg_cluster == cluster].sort_values("score").values.flatten()
                df[df.frame_nos == df[df.avg_cluster == cluster].sort_values("score").frame_nos.values[0]].loc[:, "category": "bbox4"].values.flatten()
            )
            fnos.append(
                df[df.avg_cluster == cluster].sort_values("score").frame_nos.values[0]
            )
        except:
#             Case where either the predictions are low or only 1/0 clusters exist
            pass

    return fnos, frame_vecs

# %%
def get_index_from_category(category, category_index):
    '''
    Function to return the inverse mapping from category_index (the dict with all the category names)
    '''
    for key in category_index.keys():
        if category_index[key]['name'] == category:
            return key

def search(biglist, smallist):
    for i in range(len(biglist)):
        if smallist in biglist[i]:
            return i, biglist[i].index(smallist)
    return None, None


def read_video(path, progress=True):
    '''
    Given the path, reads the video and returns the frames from the video
    '''
    frames = []

    video_reel = cv2.VideoCapture(path)
    fnos = int(video_reel.get(cv2.CAP_PROP_FRAME_COUNT))
    succ , frame = video_reel.read()
    if progress:
        with tqdm(total=fnos) as progress:
            progress.set_description("Reading the Video")
            while succ:
                frames.append(frame)
                succ, frame = video_reel.read()
                progress.update(1)
    else:
        while succ:
            frames.append(frame)
            succ, frame = video_reel.read()

    return frames
